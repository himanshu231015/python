# %% [markdown]
# # Frist Half

# %%
print("hello indore")
# Out:
# hello indore

# %%
a=70
b=80
c=a+b
print(c)
# Out:
# 150

# %%
a=int(input('A='))
b=int(input('b='))
c=a+b
print(c)
# Out:
# 50

# %%
a=(input('A='))
b=(input('b='))
c=a+b
print(c)
# Out:
# ghghghghhhhh

# %%
a=int(input('A='))
b=int(input('b='))
c=a*b
print(c)
# Out:
# 600

# %%
print(bin(c))
# Out:
# 0b1001011000

# %%
a=(input('A='))
b=int(input('b='))
c=a*b
print(c)
# Out:
# himahima

# %%
a=int(input('A='))
b=int(input('b='))
c=a//b
print(c)
# Out:
# 9.0

# %%
a=int(input('A='))

c=a**2
print(c)
# Out:
# 9

# %%
a=int(input('A='))
b=int(input('b='))
c=a**b
print(c)
# Out:
# 8

# %%
## Echange two variable without using third variable.
a=10
b=20
a,b=b,a
print(a,b)
# Another method

a = a ^ b
b = a ^ b
a = a ^ b
print("a=")
# Out:
# 20 10

# %%
a='Amit'
b="Amit"
print(a>=b)
print(type(a))
print(type(b))
# Out:
# True
# <class 'str'>
# <class 'str'>

# %%
a=200
b=200
c=200
d=200
print(id(a))
print(id(b))
print(id(c))
print(id(d))
c=500
print(id(c))
# Out:
# 140714031338136
# 140714031338136
# 140714031338136
# 140714031338136
# 2554148802736

# %%
if a==200:
    print("hello")
else:
    print("nothing")
# Out:
# hello

# %%
a=int(input("number"))
if a&1:
    print("Odd")
else:
    print("Even")
# Out:
# Odd

# %% [markdown]
# Identity Opreater = use identity opreater for address comparison
# 1.is
# 2.is not
# membership opreater = to check whether the given object given collection
# 1.in
# 2.not in

# %%
a="jp"
b="jp"
a is b
print(id(b))
# Out:
# 2554085326592

# %% [markdown]
# # Second half

# %%
def sum_sub(a,b):
    x=a+b
    y=a-b
    return x,y
a=int(input("A"))
b=int(input("b"))
c,d=sum_sub(a,b)
print(c)
print(d)
# Out:
# 130
# 70

# %% [markdown]
# ### Type of Argument
#
# 1.positoinal Argument
# 2.Keyword Argument
# 3.default Argument
# 4.Variable lenght Argument

# %% [markdown]
# 1.positoinal Argument

# %%
def Arithmetic(x,y):
    sum=x+y
    sub=x-y
    Mul=x*y
    div=x/y
    return sum,sub,Mul,div

x=int(input("X is: "))
y=int(input("Y is :"))
list=Arithmetic(x,y)
# print("the result")
# for i in list:
#     print(i)
print(type(list))
# Out:
# <class 'tuple'>

# %% [markdown]
# 2.Keyword Argument

# %%
def keyfun(name,msg):
    print("Welcomo",name,msg)

keyfun(name="Himanshu",msg="Good Morning")
keyfun(msg="Good Morning",name="Vijay")
# Out:
# Welcomo Himanshu Good Morning
# Welcomo Vijay Good Morning

# %%
def data(name,add,mob,un,pw):
    print(name,add,mob,un,pw)

data(name="him",add="indb",mob=88778877,un="ki001",pw="pass")
data(pw="pass",name="him",add="indb",mob=88778877,un="ki001")
data(name="him",pw="pass",add="indb",mob=88778877,un="ki001")
data(name="him",add="indb",pw="pass",mob=88778877,un="ki001")
data(add="indb",mob=88778877,un="ki001",pw="pass",name="him")
# Out:
# him indb 88778877 ki001 pass
# him indb 88778877 ki001 pass
# him indb 88778877 ki001 pass
# him indb 88778877 ki001 pass
# him indb 88778877 ki001 pass

# %% [markdown]
# 3.default Argument

# %%
def Deffun(Name="my baby"):
    print("Welcom ",Name)
Deffun()
Deffun(Name="Suku")
# Out:
# Welcom  my baby
# Welcom  Suku

# %%
def sum(*n):
    t=0
    for i in n:
        t=t+i
    print(t)


sum(10)
sum(10,20)
sum(10,20,30)
sum(10,20,30,40)
# Out:
# 10
# 30
# 60
# 100

# %% [markdown]
# 4.Variable lenght Argument
#     1. Golble Variable
#     2. Local Variable

# %%
a=10
def add():
    global a
    a=777
    print(a)
def add1():
    print(a)

add()
add1()
# Out:
# 777

# %% [markdown]
# lembda Expression

# %%
s=lambda n:n*n
print("The Square of 4 is: ",s(4))
print("The Square of 5 is: ",s(5))
# Out:
# The Square of 4 is:  16
# The Square of 5 is:  25

# %%
s=lambda a,b:a+b

print("The Sum of 10,20 is: ",s(10,20))
print("The Sum of 11,22 is: ",s(11,22))
# Out:
# The Sum of 10,20 is:  30
# The Sum of 11,22 is:  33

# %%
s=lambda a,b:a if a>b else b
print("The Biggest number is: ",s(10,20))
print("The Biggest number is: ",s(170,20))
# Out:
# The Biggest number is:  20
# The Biggest number is:  170

# %%
def outer():
    print("outer function is calling")
    def inner():
        print("Inner function ")
    print("Outer function calling inner function")
    inner()
outer()
# Out:
# outer function is calling
# Outer function calling inner function
# Inner function

# %% [markdown]
# Module = a group of function , variable and classes saved to a file , which is noothing but module.

# %%
import jmath as j
j.add(200,300)
# Out:
# sum  500

# %%
from jmath import add,sub
import sys
sub(100,50)
# Out:
# 50

# %%
import sys
sys.stdin
sys.stdout
sys.stderr
print(sys.argv[0])
print(sys.argv[1])
# Out:
# c:\Users\himan\anaconda3\Lib\site-packages\ipykernel_launcher.py
# --f=c:\Users\himan\AppData\Roaming\jupyter\runtime\kernel-v3a9a30ffa20204704053c0e916af2c6a96cd3ea62.json

# %%
sys.getsizeof(int)
# Out:
# 432

# %%
sys.version
# Out:
# '3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]'

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=12, micro=4, releaselevel='final', serial=0)

# %%
sys.path
# Out:
# ['c:\\Users\\himan\\Documents\\01-Code\\01-Python\\Python\\1_python\\Python_Workshope',
#  'c:\\Users\\himan\\anaconda3\\python312.zip',
#  'c:\\Users\\himan\\anaconda3\\DLLs',
#  'c:\\Users\\himan\\anaconda3\\Lib',
#  'c:\\Users\\himan\\anaconda3',
#  '',
#  'c:\\Users\\himan\\anaconda3\\Lib\\site-packages',
#  'c:\\Users\\himan\\anaconda3\\Lib\\site-packages\\win32',
#  'c:\\Users\\himan\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'c:\\Users\\himan\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
sys.platform
# Out:
# 'win32'

# %%
import os
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.getpid
# Out:
# <function nt.getpid()>

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.mkdir
# Out:
# <function nt.mkdir(path, mode=511, *, dir_fd=None)>
